# %%
import pandas as pd

# %%
df = pd.read_excel("../dataset/spring_data.xlsx")

# %%
df
# Out:
#                                           Unnamed: 0  \
# 0    Class Schedule for Spring 2025 (Undergraduate)
# 1                                                NaN
# 2                                          Day /Time
# 3                                           Sun &Tue
# 4                                                NaN
# ..                                               ...
# 166                                              NaN
# 167                                              NaN
# 168                                              NaN
# 169                                              NaN
# 170                                              NaN
#
#                                             Unnamed: 1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                       8:00 - 9:20 am
# 3                        BUS 1101 - 7 - PD 306  - SHCY
# 4                          BUS 1301 - 4 - PD 109 - ShS
# ..                                                 ...
# 166                       Note about Blended Classes:
# 167  These courses will have one online and one off...
# 168                                                NaN
# 169                         Note about Class Schedule:
# 170   Thursday and Saturday is a new class slot to ...
#
#                       Unnamed: 2                     Unnamed: 3  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                9:25 - 10:45 am             10:50 - 12 : 10 pm
# 3    BUS 1201 - 7 - PA 211 - NMK  BBS 2102 - 1 - PA 403 - SharN
# 4    BUS 1201 - 9 - PD 104 - EAZ   BBS 2201 - 1 - PA 211 -  BAK
# ..                           ...                            ...
# 166                          NaN                            NaN
# 167                          NaN                            NaN
# 168                          NaN                            NaN
# 169                          NaN                            NaN
# 170                          NaN                            NaN
#
#                       Unnamed: 4                      Unnamed: 5  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2              12:15 : 1 : 35 pm                1 : 40 : 3:00 pm
# 3    BUS 1101 - 2 - PD 203 - ArI  BBS 1201 - 01 - PA 209 - SharN
# 4     BBS 1202 - 1 - PA 407 - LA     BBS 1301 - 1 - PA 408 - SAT
# ..                           ...                             ...
# 166                          NaN                             NaN
# 167                          NaN                             NaN
# 168                          NaN                             NaN
# 169                          NaN                             NaN
# 170                          NaN                             NaN
#
#                        Unnamed: 6                    Unnamed: 7
# 0                             NaN                           NaN
# 1                             NaN                    21-12-2024
# 2                3 : 05 - 4:25 pm              4 : 30 - 5:50 pm
# 3    BBS 1101 - 1 - PC 205 - SRAL  BUS 1101 - 8 - PD 203 - STHK
# 4      BBS 2303 - 1 - PD 208 - LA    BUS 1201 - 8 - PD 109 - SA
# ..                            ...                           ...
# 166                           NaN                           NaN
# 167                           NaN                           NaN
# 168                           NaN                           NaN
# 169                           NaN                           NaN
# 170                           NaN                           NaN
#
# [171 rows x 8 columns]

# %%
def faculty_df(df): 
    df = df.iloc[140:164, 1:]
    df = pd.concat([df[column] for column in df.columns], ignore_index=True)
    df.dropna(inplace = True)
    df = df.str.split('-', n=1, expand = True)
    df.rename(columns={0: 'code', 1: 'name'}, inplace = True)
    df.loc[:, 'code'] = df.loc[:, 'code'].apply(lambda s: s.strip())
    df.loc[:, 'name'] = df.loc[:, 'name'].apply(lambda s: s.strip())
    
    return df

# %%
faculty_names = faculty_df(df)
faculty_names.head()
# Out:
#     code                              name
# 0   AAhM                        Azaz Ahmed
# 1  AAhMM                  Arwin Ahmad Mitu
# 2   AAMM                Abdullah Al Mahmud
# 3    AAR  Ahmed Abidur Razzaque Khan (GED)
# 4    AbM                      Abdul Mannan
